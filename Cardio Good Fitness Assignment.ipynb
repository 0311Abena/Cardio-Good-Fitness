# %%
ls
# Out:
#  Volume in drive C is Local Disk
#  Volume Serial Number is D4F8-5A68
#
#  Directory of C:\Users\SERWAH\Desktop\Ailead\Pandas
#
# 04/07/2023  09:26 PM           466,262  Cardio Good Fitness.ipynb
# 04/07/2023  09:27 PM    <DIR>          .
# 04/07/2023  07:53 PM    <DIR>          ..
# 04/07/2023  06:09 PM    <DIR>          .ipynb_checkpoints
# 07/10/2022  06:11 PM           204,794 acw_user_data.csv
# 04/07/2023  10:36 AM         3,811,656 adult_data.csv
# 04/07/2023  12:18 PM           463,808 Ailead canvas homeworks.ipynb
# 08/24/2022  03:03 PM           552,435 books (1).csv
# 08/24/2022  03:03 PM           552,435 books.csv
# 04/07/2023  09:26 PM           466,262 Cardio Good Fitness Assignment.ipynb
# 04/07/2023  06:08 PM             7,460 CardioGoodFitness.csv
# 03/28/2023  02:50 PM           666,693 census_cleaned.csv
# 03/13/2023  04:26 PM           660,754 census10 - Copy.csv
# 03/13/2023  04:26 PM           660,754 census10.csv
# ...

# %%
# import the libraries
import pandas as pd
# import pandas_profiling
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# pd.set_option('display.max_rows',None)

# %%
# load the dataset

cardio_df = pd.read_csv("CardioGoodFitness.csv")
df = pd.read_csv("CardioGoodFitness.csv")
cardio_df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income
# 0     TM195   18    Male         14        Single      3        4   29562  \
# 1     TM195   19    Male         15        Single      2        3   31836
# 2     TM195   19  Female         14     Partnered      4        3   30699
# 3     TM195   19    Male         12        Single      3        3   32973
# 4     TM195   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
# Print out the columns in the dataset
cardio_df.columns
# Out:
# Index(['Product', 'Age', 'Gender', 'Education', 'MaritalStatus', 'Usage',
#        'Fitness', 'Income', 'Miles'],
#       dtype='object')

# %%
# Print the first 5 rows
cardio_df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
# check the dimension
cardio_df.shape
# Out:
# (180, 9)

# %% [markdown]
# We have 180 rows and 9 columns in the csv dataset

# %%
# check the data types
cardio_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %% [markdown]
# We have nine columns with 3 columns being object type, and 6 columns being integer type

# %%
# We finding the statistical descriptive analysis of the categories
cardio_df.describe(include = "all")
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage
# count      180  180.000000    180  180.000000           180  180.000000  \
# unique       3         NaN      2         NaN             2         NaN
# top      TM195         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %% [markdown]
# From Age we can tell that the highest age is 50 and the lowest is 18 years with mean of 28.79 and median of 26. We can also tell that we have 25% of the customers equal or under 24 years and 75% are above 33 years. We can tell this is a relatively young group.
#
# We can also tell that there are alot more males than female at Gender .

# %%
# check the null
cardio_df.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %% [markdown]
# We have no null values in the data set

# %%
# checking empty values in the data set
column_list = cardio_df.columns
column_list.values.tolist()

columns_with_empty_values = []
for column in column_list:
    if cardio_df[cardio_df[str(column)] == ' '].shape[0] > 0:
        columns_with_empty_values.append(column)
print(columns_with_empty_values)
# Out:
# []

# %% [markdown]
# We have no empty values in the data set

# %%
# Index(['Product', 'Age', 'Gender', 'Education', 'MaritalStatus', 'Usage',
#        'Fitness', 'Income', 'Miles'],
#       dtype='object')

# %% [markdown]
# Univariate Data Analysis
# - Analysis of spread and distribution of every feature in the dataset.

# %%
# Product
product_plt = sns.histplot(x = 'Product', binwidth = 2, data= cardio_df)

# %%
# we create age histogram
age_plt = sns.histplot(x = 'Age', binwidth = 5, data= cardio_df)

# add labels and heading
# plt.hist(age, bins = 5)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title ('Age Distribution')

#plot the age histogram
plt.show()

# %% [markdown]
# We notice the customers are not aged and with majority between the ages of 23 and 29

# %%
# Gender
sns.countplot(x='Gender', data=cardio_df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %% [markdown]
# We notice the male customers are more than the female

# %%
# Education
sns.countplot(x='Education', data=cardio_df)
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %%
# MaritalStatus
sns.countplot(x='MaritalStatus', data=cardio_df)
# Out:
# <Axes: xlabel='MaritalStatus', ylabel='count'>

# %%
# Usage
sns.histplot(df['Usage'])
# Out:
# <Axes: xlabel='Usage', ylabel='Count'>

# %%
# Fitness
sns.histplot(df['Fitness'])
# Out:
# <Axes: xlabel='Fitness', ylabel='Count'>

# %%
# Income
sns.histplot(df['Income'])
# Out:
# <Axes: xlabel='Income', ylabel='Count'>

# %%
# Miles
sns.histplot(df['Miles'])
# Out:
# <Axes: xlabel='Miles', ylabel='Count'>

# %% [markdown]
# Multivariate Data Analysis
# - Analysis of interaction between features, in the dataset

# %%
#using only numerical categories
sns.pairplot(data = cardio_df)

# %%
# Select only numerical columns
num_cols = cardio_df.select_dtypes(include=['int64']).columns

# Calculate correlation matrix
corr_matrix = cardio_df[num_cols].corr()

# Visualize correlation matrix using heatmap
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
cardio_df.corr
# Out:
# <bound method DataFrame.corr of     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income
# 0     TM195   18    Male         14        Single      3        4   29562  \
# 1     TM195   19    Male         15        Single      2        3   31836
# 2     TM195   19  Female         14     Partnered      4        3   30699
# 3     TM195   19    Male         12        Single      3        3   32973
# 4     TM195   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# ...

# %% [markdown]
# The heatmap shows the paired correlation between every column in the dataset. The correlation coefficient ranges from -1 to 1, where -1 implies a perfect negative correlation, 0 implies no correlation, and 1 implies a perfect positive correlation.
#
# Based on the heatmap, we can see that there is a moderate positive correlation between the following pairs of columns:
#
# Usage and Fitness (correlation coefficient of 0.67)
# Fitness and Miles (correlation coefficient of 0.79)
#
# We notice a weak positive correlation between Income and Miles (correlation coefficient of 0.51).
#
# In conclusion, there is no strong correlation between any of the columns.
